# %% [markdown]
# # Step 1: Import necessary libraries

# %%
import os
import googlemaps
import sys

# Add the project root to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
if project_root not in sys.path:
    sys.path.append(project_root)
from app.database import create_connection

# %% [markdown]
# # Step 2: Set up Google Maps API key

# %%
from app.config import Config
GOOGLE_MAPS_API_KEY = Config.GOOGLE_MAPS_API_KEY  # Load from environment variable
api_key = googlemaps.Client(key=GOOGLE_MAPS_API_KEY)

# %% [markdown]
# # Step 3: Fetch coordinates using Google Maps API

# %%
import requests
def format_address(name):
    """
    Formats the address by combining name and location for the API request.
    """
    formatted = f"{name}, York University, Toronto, ON, Canada".replace("&", "and").replace(",", "").replace(" ", "+")
    return formatted

def get_coordinates(address):
    """
    Fetches the latitude and longitude for a given address using Google Maps Geocoding API.
    """
    if not api_key:
        raise Exception("GOOGLE_MAPS_API_KEY not set in environment variables.")
    
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {"address": address, "key": GOOGLE_MAPS_API_KEY}
    response = requests.get(base_url, params=params)

    if response.status_code != 200:
        print(f"HTTP Error {response.status_code} for address {address}")
        return None, None

    data = response.json()
    if data["status"] != "OK":
        print(f"Geocoding API error for {address}: {data['status']}")
        return None, None

    location = data["results"][0]["geometry"]["location"]
    return location["lat"], location["lng"]

# %% [markdown]
# # Step 4: Update location data in the database

# %%
import time
def update_location_for_table(table_name, id_column, name_column, location_column):
    """
    Iterates through all rows in the table, retrieves coordinates, and updates the location.
    """
    print(f"Updating locations for table: {table_name}...")

    connection = create_connection()
    if connection is None:
        print("Failed to connect to the database.")
        return

    try:
        cursor = connection.cursor(dictionary=True)
        # Fetch records
        query = f"SELECT {id_column}, {name_column}, {location_column} FROM {table_name}"
        print(f"Executing query: {query}")
        cursor.execute(query)
        rows = cursor.fetchall()
        print(f"Fetched rows: {rows}")

        for row in rows:
            record_id = row[id_column]
            name = row[name_column]
            location = row[location_column]

            print(f"Processing Record ID: {record_id}, Name: {name}, Existing Location: {location}")
            
            # Format address for API call
            formatted_address = format_address(name)
            print(f"Formatted address: {formatted_address}")

            lat, lng = get_coordinates(formatted_address)
            if lat is None or lng is None:
                print(f"Coordinates not found for {name}. Skipping...")
                continue
            
            print(f"Fetched Coordinates for {name}: ({lat}, {lng})")
            
            # Update the database
            update_query = f"UPDATE {table_name} SET {location_column} = ST_GeomFromText('POINT(%s %s)') WHERE {id_column} = %s"
            cursor.execute(update_query, (lng, lat, record_id))  # Note: lng first, then lat
            connection.commit()
            print(f"Updated {table_name} ID {record_id} with coordinates: {lat}, {lng}")
            time.sleep(0.2)  # To avoid hitting rate limits
            
    except Exception as e:
        print(f"Error updating {table_name}: {e}")
    finally:
        print(f"Finished updating {table_name}.")

def fetch_and_print_locations_for_table(table_name, id_column, name_column, location_column):
    """
    Iterates through all rows in the table, retrieves coordinates, and prints them without updating the database.
    """
    print(f"Fetching and printing locations for table: {table_name}...")

    connection = create_connection()
    if connection is None:
        print("Failed to connect to the database.")
        return

    try:
        cursor = connection.cursor(dictionary=True)
        # Fetch records
        query = f"SELECT {id_column}, {name_column}, {location_column} FROM {table_name}"
        cursor.execute(query)
        rows = cursor.fetchall()

        for row in rows:
            record_id = row[id_column]
            name = row[name_column]
            location = row[location_column]

            formatted_address = format_address(name)
            print(f"Fetching coordinates for: {formatted_address}")

            lat, lng = get_coordinates(formatted_address)
            if lat is None or lng is None:
                print(f"Coordinates not found for {name}. Skipping...")
                continue

            # Print the results
            print(f"Record ID: {record_id}, Name: {name}, Coordinates: ({lat}, {lng})")
            time.sleep(0.2)  # To avoid hitting rate limits
    except Exception as e:
        print(f"Error fetching locations for {table_name}: {e}")
    finally:
        print(f"Finished fetching locations for {table_name}.")

# %% [markdown]
# # Step 5: Main script

# %%
# Fetch and print libraries
fetch_and_print_locations_for_table("libraries", "library_id", "name", "location")
# Fetch and print cafes
fetch_and_print_locations_for_table("cafes", "cafe_id", "name", "location")
# Fetch and print buildings
fetch_and_print_locations_for_table("buildings", "building_id", "building_name", "location")
# Out:
# Fetching and printing locations for table: libraries...
# Fetching coordinates for: Scott+Library+York+University+Toronto+ON+Canada
# Record ID: 1, Name: Scott Library, Coordinates: (43.7723418, -79.5055508)
# Fetching coordinates for: Bronfman+Business+Library+York+University+Toronto+ON+Canada
# Record ID: 2, Name: Bronfman Business Library, Coordinates: (43.7734232, -79.4987993)
# Fetching coordinates for: Steacie+Science+and+Engineering+Library+York+University+Toronto+ON+Canada
# Record ID: 3, Name: Steacie Science and Engineering Library, Coordinates: (43.773608, -79.505845)
# Finished fetching locations for libraries.
# Fetching and printing locations for table: cafes...
# Fetching coordinates for: La+Prep+-+York+Lanes+York+University+Toronto+ON+Canada
# Record ID: 1, Name: La Prep - York Lanes, Coordinates: (43.7742143, -79.5018478)
# Fetching coordinates for: Break+Cafe+-+Second+Student+Center+York+University+Toronto+ON+Canada
# Record ID: 2, Name: Break Cafe - Second Student Center, Coordinates: (43.7715346, -79.503864)
# Fetching coordinates for: Starbucks+-+ACW+York+University+Toronto+ON+Canada
# Record ID: 3, Name: Starbucks - ACW, Coordinates: (43.653226, -79.3831843)
# Fetching coordinates for: Starbucks+-+Central+Square+York+University+Toronto+ON+Canada
# Record ID: 4, Name: Starbucks - Central Square, Coordinates: (43.7728891, -79.50489999999999)
# Fetching coordinates for: Schulich+Market+Cafe+-+Schulich+School+of+Business+York+University+Toronto+ON+Canada
# Record ID: 5, Name: Schulich Market Cafe - Schulich School of Business, Coordinates: (43.773227, -79.498257)
# Fetching coordinates for: Aroma+Espresso+Bar+-+Pond+York+University+Toronto+ON+Canada
# Record ID: 6, Name: Aroma Espresso Bar - Pond, Coordinates: (43.7734535, -79.50186839999999)
# Fetching coordinates for: Aroma+Espresso+Bar+-+York+Lanes+York+University+Toronto+ON+Canada
# Record ID: 7, Name: Aroma Espresso Bar - York Lanes, Coordinates: (43.7742143, -79.5018478)
# Fetching coordinates for: Tim+Hortons+-+William+Small+Center+York+University+Toronto+ON+Canada
# Record ID: 8, Name: Tim Hortons - William Small Center, Coordinates: (43.77294500000001, -79.50777769999999)
# Fetching coordinates for: Tim+Hortons+-+Central+Square+York+University+Toronto+ON+Canada
# Record ID: 9, Name: Tim Hortons - Central Square, Coordinates: (43.7721373, -79.50436359999999)
# Fetching coordinates for: The+Great+Canadian+Bagel+-+York+Lanes+York+University+Toronto+ON+Canada
# Record ID: 10, Name: The Great Canadian Bagel - York Lanes, Coordinates: (43.7742143, -79.5018478)
# Finished fetching locations for cafes.
# Fetching and printing locations for table: buildings...
# Fetching coordinates for: Accolade+Building+East+York+University+Toronto+ON+Canada
# Record ID: 133, Name: Accolade Building East, Coordinates: (43.7725551, -79.4993904)
# Fetching coordinates for: Accolade+Building+West+York+University+Toronto+ON+Canada
# Record ID: 134, Name: Accolade Building West, Coordinates: (43.7725673, -79.50249029999999)
# Fetching coordinates for: Archives+of+Ontario+York+University+Toronto+ON+Canada
# Record ID: 135, Name: Archives of Ontario, Coordinates: (43.774849, -79.500379)
# Fetching coordinates for: Atkinson+York+University+Toronto+ON+Canada
# Record ID: 136, Name: Atkinson, Coordinates: (43.7711122, -79.5024153)
# Fetching coordinates for: Norman+Bethune+College+York+University+Toronto+ON+Canada
# Record ID: 137, Name: Norman Bethune College, Coordinates: (43.77298880000001, -79.5088344)
# Fetching coordinates for: Bennett+Centre+for+Student+Services+York+University+Toronto+ON+Canada
# Record ID: 138, Name: Bennett Centre for Student Services, Coordinates: (43.7723176, -79.49868049999999)
# Fetching coordinates for: Bergeron+Centre+for+Engineering+Excellence+York+University+Toronto+ON+Canada
# Record ID: 139, Name: Bergeron Centre for Engineering Excellence, Coordinates: (43.7722329, -79.50668879999999)
# Fetching coordinates for: Behavioural+Sciences+Building+York+University+Toronto+ON+Canada
# Record ID: 140, Name: Behavioural Sciences Building, Coordinates: (43.7735791, -79.5037334)
# Fetching coordinates for: Burton+Auditorium+York+University+Toronto+ON+Canada
# Record ID: 141, Name: Burton Auditorium, Coordinates: (43.7726615, -79.5018644)
# Fetching coordinates for: Chemistry+Building+York+University+Toronto+ON+Canada
# Record ID: 142, Name: Chemistry Building, Coordinates: (43.7732651, -79.5079184)
# Fetching coordinates for: Calumet+College+York+University+Toronto+ON+Canada
# Record ID: 143, Name: Calumet College, Coordinates: (43.7728461, -79.50974830000001)
# Fetching coordinates for: The+Joan+and+Martin+Goldfarb+Centre+for+Fine+Arts+York+University+Toronto+ON+Canada
# Record ID: 144, Name: The Joan & Martin Goldfarb Centre for Fine Arts, Coordinates: (43.7720368, -79.50234010000001)
# Fetching coordinates for: Centre+for+Film+and+Theatre+York+University+Toronto+ON+Canada
# Record ID: 145, Name: Centre for Film and Theatre, Coordinates: (43.7726696, -79.501145)
# Fetching coordinates for: Curtis+Lecture+Halls+York+University+Toronto+ON+Canada
# Record ID: 146, Name: Curtis Lecture Halls, Coordinates: (43.7731258, -79.5052743)
# Fetching coordinates for: Computer+Methods+Building+York+University+Toronto+ON+Canada
# Record ID: 147, Name: Computer Methods Building, Coordinates: (43.778963, -79.49566850000001)
# Fetching coordinates for: Central+Square+York+University+Toronto+ON+Canada
# Record ID: 148, Name: Central Square, Coordinates: (43.7728891, -79.50489999999999)
# Fetching coordinates for: Central+Utilities+Building+York+University+Toronto+ON+Canada
# Record ID: 149, Name: Central Utilities Building, Coordinates: (43.7775545, -79.49877269999999)
# Fetching coordinates for: Dahdaleh+Building+(formerly+TEL)+York+University+Toronto+ON+Canada
# Record ID: 150, Name: Dahdaleh Building (formerly TEL), Coordinates: (43.7711574, -79.5007935)
# Fetching coordinates for: Executive+Learning+Centre+York+University+Toronto+ON+Canada
# Record ID: 151, Name: Executive Learning Centre, Coordinates: (43.7729679, -79.4981284)
# Fetching coordinates for: Founders+College+York+University+Toronto+ON+Canada
# Record ID: 152, Name: Founders College, Coordinates: (43.77603, -79.50336)
# Fetching coordinates for: Frost+Library+(Glendon+campus)+York+University+Toronto+ON+Canada
# Record ID: 153, Name: Frost Library (Glendon campus), Coordinates: (43.7272494, -79.3761823)
# Fetching coordinates for: Farquharson+Life+Sciences+York+University+Toronto+ON+Canada
# Record ID: 154, Name: Farquharson Life Sciences, Coordinates: (43.774297, -79.5046694)
# Fetching coordinates for: Founders+Tennis+Court+York+University+Toronto+ON+Canada
# Record ID: 155, Name: Founders Tennis Court, Coordinates: (43.7747961, -79.50806949999999)
# Fetching coordinates for: Glendon+Hall+(Glendon+campus)+York+University+Toronto+ON+Canada
# Record ID: 156, Name: Glendon Hall (Glendon campus), Coordinates: (43.7277093, -79.37660989999999)
# Fetching coordinates for: Lorna+R.+Marsden+Honours+Court+and+Welcome+Centre+York+University+Toronto+ON+Canada
# Record ID: 157, Name: Lorna R. Marsden Honours Court & Welcome Centre, Coordinates: (43.774266, -79.49822569999999)
# Fetching coordinates for: Hart+House+(Osgoode+Hall+Law+School)+York+University+Toronto+ON+Canada
# Record ID: 158, Name: Hart House (Osgoode Hall Law School), Coordinates: (43.7706164, -79.50511139999999)
# Fetching coordinates for: Health+Nursing+and+Environmental+Studies+Building+York+University+Toronto+ON+Canada
# Record ID: 159, Name: Health, Nursing and Environmental Studies Building, Coordinates: (43.7712852, -79.5045715)
# Fetching coordinates for: Hilliard+Residence+(Glendon+campus)+York+University+Toronto+ON+Canada
# Record ID: 160, Name: Hilliard Residence (Glendon campus), Coordinates: (43.726258, -79.3780712)
# Fetching coordinates for: Ignat+Kaneff+Building+(Osgoode+Hall+Law+School)+York+University+Toronto+ON+Canada
# Record ID: 161, Name: Ignat Kaneff Building (Osgoode Hall Law School), Coordinates: (43.7706164, -79.50511139999999)
# Fetching coordinates for: Kinsmen+Building+York+University+Toronto+ON+Canada
# Record ID: 162, Name: Kinsmen Building, Coordinates: (43.7780012, -79.49553070000002)
# Fetching coordinates for: Kaneff+Tower+York+University+Toronto+ON+Canada
# Record ID: 163, Name: Kaneff Tower, Coordinates: (43.7747818, -79.500619)
# Fetching coordinates for: Lassonde+Building+York+University+Toronto+ON+Canada
# Record ID: 164, Name: Lassonde Building, Coordinates: (43.7742239, -79.5055648)
# Fetching coordinates for: LAandPS+@+IBM+Markham+York+University+Toronto+ON+Canada
# Record ID: 165, Name: LA&PS @ IBM Markham, Coordinates: (43.85439, -79.31151)
# Fetching coordinates for: Life+Sciences+Building+York+University+Toronto+ON+Canada
# Record ID: 166, Name: Life Sciences Building, Coordinates: (43.774174, -79.5079816)
# Fetching coordinates for: Lumbers+Building+York+University+Toronto+ON+Canada
# Record ID: 167, Name: Lumbers Building, Coordinates: (43.7748183, -79.5049999)
# Fetching coordinates for: Rob+and+Cheryl+McEwen+Graduate+Study+and+Research+Building+York+University+Toronto+ON+Canada
# Record ID: 168, Name: Rob and Cheryl McEwen Graduate Study & Research Building, Coordinates: (43.653226, -79.3831843)
# Fetching coordinates for: McLaughlin+College+York+University+Toronto+ON+Canada
# Record ID: 169, Name: McLaughlin College, Coordinates: (43.77716239999999, -79.5024348)
# Fetching coordinates for: Off+Campus+(contact+the+department+that+offers+the+course)+York+University+Toronto+ON+Canada
# Record ID: 170, Name: Off Campus (contact the department that offers the course), Coordinates: (43.65446559999999, -79.3874936)
# Fetching coordinates for: Physical+Resources+Building+York+University+Toronto+ON+Canada
# Record ID: 171, Name: Physical Resources Building, Coordinates: (43.777507, -79.4971978)
# Fetching coordinates for: Petrie+Science+and+Engineering+Building+/+Petrie+Observatory+York+University+Toronto+ON+Canada
# Record ID: 172, Name: Petrie Science and Engineering Building / Petrie Observatory, Coordinates: (43.7739317, -79.5067754)
# Fetching coordinates for: Ross+Building+York+University+Toronto+ON+Canada
# Record ID: 173, Name: Ross Building, Coordinates: (43.7722433, -79.50379219999999)
# Fetching coordinates for: Seneca+@+York+York+University+Toronto+ON+Canada
# Record ID: 175, Name: Seneca @ York, Coordinates: (43.7734535, -79.50186839999999)
# Fetching coordinates for: Stong+College+York+University+Toronto+ON+Canada
# Record ID: 176, Name: Stong College, Coordinates: (43.7728139, -79.5087235)
# Fetching coordinates for: Scott+Library+York+University+Toronto+ON+Canada
# Record ID: 177, Name: Scott Library, Coordinates: (43.7723418, -79.5055508)
# Fetching coordinates for: Sherman+Health+Science+Research+Centre+York+University+Toronto+ON+Canada
# Record ID: 178, Name: Sherman Health Science Research Centre, Coordinates: (43.7752117, -79.51194679999999)
# Fetching coordinates for: Stedman+Lecture+Halls+York+University+Toronto+ON+Canada
# Record ID: 179, Name: Stedman Lecture Halls, Coordinates: (43.7743997, -79.50318419999999)
# Fetching coordinates for: Seymour+Schulich+Building+York+University+Toronto+ON+Canada
# Record ID: 180, Name: Seymour Schulich Building, Coordinates: (43.7734608, -79.4991869)
# Fetching coordinates for: Sheridan+College+-+Trafalgar+Campus+York+University+Toronto+ON+Canada
# Record ID: 181, Name: Sheridan College - Trafalgar Campus, Coordinates: (43.7729946, -79.5035369)
# Fetching coordinates for: Student+Centre+York+University+Toronto+ON+Canada
# Record ID: 182, Name: Student Centre, Coordinates: (43.7738625, -79.50316190000001)
# Fetching coordinates for: Steacie+Science+and+Engineering+Library+York+University+Toronto+ON+Canada
# Record ID: 183, Name: Steacie Science and Engineering Library, Coordinates: (43.773608, -79.505845)
# Fetching coordinates for: Tennis+Canada+(TC+Sobeys)+York+University+Toronto+ON+Canada
# Record ID: 184, Name: Tennis Canada (TC Sobeys), Coordinates: (43.7707159, -79.5115709)
# Fetching coordinates for: Technology+and+Enhanced+Learning+Building+(effective+summer+2016+Dahdaleh+Building+DB)+York+University+Toronto+ON+Canada
# Record ID: 185, Name: Technology and Enhanced Learning Building (effective summer 2016, Dahdaleh Building, DB), Coordinates: (43.7711574, -79.5007935)
# Fetching coordinates for: Track+and+Field+Centre+York+University+Toronto+ON+Canada
# Record ID: 186, Name: Track and Field Centre, Coordinates: (43.7763564, -79.50766449999999)
# Fetching coordinates for: Tait+McKenzie+Centre+(East/West)+York+University+Toronto+ON+Canada
# Record ID: 187, Name: Tait McKenzie Centre (East/West), Coordinates: (43.7742311, -79.5094038)
# Fetching coordinates for: Tait+Tennis+Courts+York+University+Toronto+ON+Canada
# Record ID: 188, Name: Tait Tennis Courts, Coordinates: (43.7747961, -79.50806949999999)
# Fetching coordinates for: Vanier+College+York+University+Toronto+ON+Canada
# Record ID: 189, Name: Vanier College, Coordinates: (43.7755814, -79.50221479999999)
# Fetching coordinates for: Vari+Hall+York+University+Toronto+ON+Canada
# Record ID: 190, Name: Vari Hall, Coordinates: (43.7730972, -79.5034042)
# Fetching coordinates for: Winters+College+York+University+Toronto+ON+Canada
# Record ID: 191, Name: Winters College, Coordinates: (43.77613030000001, -79.50160919999999)
# Fetching coordinates for: West+Office+Building+York+University+Toronto+ON+Canada
# Record ID: 192, Name: West Office Building, Coordinates: (43.7753202, -79.50811759999999)
# Fetching coordinates for: William+Small+Centre+York+University+Toronto+ON+Canada
# Record ID: 193, Name: William Small Centre, Coordinates: (43.77294500000001, -79.50777769999999)
# Fetching coordinates for: York+Hall+(Glendon+campus)+York+University+Toronto+ON+Canada
# Record ID: 194, Name: York Hall (Glendon campus), Coordinates: (43.727296, -79.3790337)
# Fetching coordinates for: York+Lanes+York+University+Toronto+ON+Canada
# Record ID: 195, Name: York Lanes, Coordinates: (43.7742143, -79.5018478)
# Fetching coordinates for: York+Student+Fieldhouse+(East/West)+(Tait+McKenzie+Building)+York+University+Toronto+ON+Canada
# Record ID: 196, Name: York Student Fieldhouse (East/West) (Tait McKenzie Building), Coordinates: (43.7745284, -79.5096745)
# Fetching coordinates for: York+Student+Fieldhouse+(East+side+only)+(Tait+McKenzie+Building)+York+University+Toronto+ON+Canada
# Record ID: 197, Name: York Student Fieldhouse (East side only) (Tait McKenzie Building), Coordinates: (43.7745284, -79.5096745)
# Fetching coordinates for: York+Student+Fieldhouse+(West+side+only)+(Tait+McKenzie+Building)+York+University+Toronto+ON+Canada
# Record ID: 198, Name: York Student Fieldhouse (West side only) (Tait McKenzie Building), Coordinates: (43.7745284, -79.5096745)
# Finished fetching locations for buildings.

# %%
# Update libraries
update_location_for_table("libraries", "library_id", "name", "location")
# Update cafes
update_location_for_table("cafes", "cafe_id", "name", "location")
# Update buildings
update_location_for_table("buildings", "building_id", "building_name", "location")
# Out:
# Updating locations for table: libraries...
# Executing query: SELECT library_id, name, location FROM libraries
# Fetched rows: [{'library_id': 1, 'name': 'Scott Library', 'location': ''}, {'library_id': 2, 'name': 'Bronfman Business Library', 'location': ''}, {'library_id': 3, 'name': 'Steacie Science and Engineering Library', 'location': ''}]
# Processing Record ID: 1, Name: Scott Library, Existing Location:
# Formatted address: Scott+Library+York+University+Toronto+ON+Canada
# Fetched Coordinates for Scott Library: (43.7723418, -79.5055508)
# Updated libraries ID 1 with coordinates: 43.7723418, -79.5055508
# Processing Record ID: 2, Name: Bronfman Business Library, Existing Location:
# Formatted address: Bronfman+Business+Library+York+University+Toronto+ON+Canada
# Fetched Coordinates for Bronfman Business Library: (43.7734232, -79.4987993)
# Updated libraries ID 2 with coordinates: 43.7734232, -79.4987993
# Processing Record ID: 3, Name: Steacie Science and Engineering Library, Existing Location:
# Formatted address: Steacie+Science+and+Engineering+Library+York+University+Toronto+ON+Canada
# Fetched Coordinates for Steacie Science and Engineering Library: (43.773608, -79.505845)
# Updated libraries ID 3 with coordinates: 43.773608, -79.505845
# Finished updating libraries.
# Updating locations for table: cafes...
# Executing query: SELECT cafe_id, name, location FROM cafes
# Fetched rows: [{'cafe_id': 1, 'name': 'La Prep - York Lanes', 'location': ''}, {'cafe_id': 2, 'name': 'Break Cafe - Second Student Center', 'location': ''}, {'cafe_id': 3, 'name': 'Starbucks - ACW', 'location': ''}, {'cafe_id': 4, 'name': 'Starbucks - Central Square', 'location': ''}, {'cafe_id': 5, 'name': 'Schulich Market Cafe - Schulich School of Business', 'location': ''}, {'cafe_id': 6, 'name': 'Aroma Espresso Bar - Pond', 'location': ''}, {'cafe_id': 7, 'name': 'Aroma Espresso Bar - York Lanes', 'location': ''}, {'cafe_id': 8, 'name': 'Tim Hortons - William Small Center', 'location': ''}, {'cafe_id': 9, 'name': 'Tim Hortons - Central Square', 'location': ''}, {'cafe_id': 10, 'name': 'The Great Canadian Bagel - York Lanes', 'location': ''}]
# Processing Record ID: 1, Name: La Prep - York Lanes, Existing Location:
# Formatted address: La+Prep+-+York+Lanes+York+University+Toronto+ON+Canada
# Fetched Coordinates for La Prep - York Lanes: (43.7742143, -79.5018478)
# Updated cafes ID 1 with coordinates: 43.7742143, -79.5018478
# Processing Record ID: 2, Name: Break Cafe - Second Student Center, Existing Location:
# Formatted address: Break+Cafe+-+Second+Student+Center+York+University+Toronto+ON+Canada
# Fetched Coordinates for Break Cafe - Second Student Center: (43.7715346, -79.503864)
# Updated cafes ID 2 with coordinates: 43.7715346, -79.503864
# Processing Record ID: 3, Name: Starbucks - ACW, Existing Location:
# Formatted address: Starbucks+-+ACW+York+University+Toronto+ON+Canada
# Fetched Coordinates for Starbucks - ACW: (43.653226, -79.3831843)
# Updated cafes ID 3 with coordinates: 43.653226, -79.3831843
# Processing Record ID: 4, Name: Starbucks - Central Square, Existing Location:
# Formatted address: Starbucks+-+Central+Square+York+University+Toronto+ON+Canada
# Fetched Coordinates for Starbucks - Central Square: (43.7728891, -79.50489999999999)
# Updated cafes ID 4 with coordinates: 43.7728891, -79.50489999999999
# Processing Record ID: 5, Name: Schulich Market Cafe - Schulich School of Business, Existing Location:
# Formatted address: Schulich+Market+Cafe+-+Schulich+School+of+Business+York+University+Toronto+ON+Canada
# Fetched Coordinates for Schulich Market Cafe - Schulich School of Business: (43.773227, -79.498257)
# Updated cafes ID 5 with coordinates: 43.773227, -79.498257
# Processing Record ID: 6, Name: Aroma Espresso Bar - Pond, Existing Location:
# Formatted address: Aroma+Espresso+Bar+-+Pond+York+University+Toronto+ON+Canada
# Fetched Coordinates for Aroma Espresso Bar - Pond: (43.7734535, -79.50186839999999)
# Updated cafes ID 6 with coordinates: 43.7734535, -79.50186839999999
# Processing Record ID: 7, Name: Aroma Espresso Bar - York Lanes, Existing Location:
# Formatted address: Aroma+Espresso+Bar+-+York+Lanes+York+University+Toronto+ON+Canada
# Fetched Coordinates for Aroma Espresso Bar - York Lanes: (43.7742143, -79.5018478)
# Updated cafes ID 7 with coordinates: 43.7742143, -79.5018478
# Processing Record ID: 8, Name: Tim Hortons - William Small Center, Existing Location:
# Formatted address: Tim+Hortons+-+William+Small+Center+York+University+Toronto+ON+Canada
# Fetched Coordinates for Tim Hortons - William Small Center: (43.77294500000001, -79.50777769999999)
# Updated cafes ID 8 with coordinates: 43.77294500000001, -79.50777769999999
# Processing Record ID: 9, Name: Tim Hortons - Central Square, Existing Location:
# Formatted address: Tim+Hortons+-+Central+Square+York+University+Toronto+ON+Canada
# Fetched Coordinates for Tim Hortons - Central Square: (43.7721373, -79.50436359999999)
# Updated cafes ID 9 with coordinates: 43.7721373, -79.50436359999999
# Processing Record ID: 10, Name: The Great Canadian Bagel - York Lanes, Existing Location:
# Formatted address: The+Great+Canadian+Bagel+-+York+Lanes+York+University+Toronto+ON+Canada
# Fetched Coordinates for The Great Canadian Bagel - York Lanes: (43.7742143, -79.5018478)
# Updated cafes ID 10 with coordinates: 43.7742143, -79.5018478
# Finished updating cafes.
# Updating locations for table: buildings...
# Executing query: SELECT building_id, building_name, location FROM buildings
# Fetched rows: [{'building_id': 133, 'building_name': 'Accolade Building East', 'location': ''}, {'building_id': 134, 'building_name': 'Accolade Building West', 'location': ''}, {'building_id': 135, 'building_name': 'Archives of Ontario', 'location': ''}, {'building_id': 136, 'building_name': 'Atkinson', 'location': ''}, {'building_id': 137, 'building_name': 'Norman Bethune College', 'location': ''}, {'building_id': 138, 'building_name': 'Bennett Centre for Student Services', 'location': ''}, {'building_id': 139, 'building_name': 'Bergeron Centre for Engineering Excellence', 'location': ''}, {'building_id': 140, 'building_name': 'Behavioural Sciences Building', 'location': ''}, {'building_id': 141, 'building_name': 'Burton Auditorium', 'location': ''}, {'building_id': 142, 'building_name': 'Chemistry Building', 'location': ''}, {'building_id': 143, 'building_name': 'Calumet College', 'location': ''}, {'building_id': 144, 'building_name': 'The Joan & Martin Goldfarb Centre for Fine Arts', 'location': ''}, {'building_id': 145, 'building_name': 'Centre for Film and Theatre', 'location': ''}, {'building_id': 146, 'building_name': 'Curtis Lecture Halls', 'location': ''}, {'building_id': 147, 'building_name': 'Computer Methods Building', 'location': ''}, {'building_id': 148, 'building_name': 'Central Square', 'location': ''}, {'building_id': 149, 'building_name': 'Central Utilities Building', 'location': ''}, {'building_id': 150, 'building_name': 'Dahdaleh Building (formerly TEL)', 'location': ''}, {'building_id': 151, 'building_name': 'Executive Learning Centre', 'location': ''}, {'building_id': 152, 'building_name': 'Founders College', 'location': ''}, {'building_id': 153, 'building_name': 'Frost Library (Glendon campus)', 'location': ''}, {'building_id': 154, 'building_name': 'Farquharson Life Sciences', 'location': ''}, {'building_id': 155, 'building_name': 'Founders Tennis Court', 'location': ''}, {'building_id': 156, 'building_name': 'Glendon Hall (Glendon campus)', 'location': ''}, {'building_id': 157, 'building_name': 'Lorna R. Marsden Honours Court & Welcome Centre', 'location': ''}, {'building_id': 158, 'building_name': 'Hart House (Osgoode Hall Law School)', 'location': ''}, {'building_id': 159, 'building_name': 'Health, Nursing and Environmental Studies Building', 'location': ''}, {'building_id': 160, 'building_name': 'Hilliard Residence (Glendon campus)', 'location': ''}, {'building_id': 161, 'building_name': 'Ignat Kaneff Building (Osgoode Hall Law School)', 'location': ''}, {'building_id': 162, 'building_name': 'Kinsmen Building', 'location': ''}, {'building_id': 163, 'building_name': 'Kaneff Tower', 'location': ''}, {'building_id': 164, 'building_name': 'Lassonde Building', 'location': ''}, {'building_id': 165, 'building_name': 'LA&PS @ IBM Markham', 'location': ''}, {'building_id': 166, 'building_name': 'Life Sciences Building', 'location': ''}, {'building_id': 167, 'building_name': 'Lumbers Building', 'location': ''}, {'building_id': 168, 'building_name': 'Rob and Cheryl McEwen Graduate Study & Research Building', 'location': ''}, {'building_id': 169, 'building_name': 'McLaughlin College', 'location': ''}, {'building_id': 170, 'building_name': 'Off Campus (contact the department that offers the course)', 'location': ''}, {'building_id': 171, 'building_name': 'Physical Resources Building', 'location': ''}, {'building_id': 172, 'building_name': 'Petrie Science and Engineering Building / Petrie Observatory', 'location': ''}, {'building_id': 173, 'building_name': 'Ross Building', 'location': ''}, {'building_id': 175, 'building_name': 'Seneca @ York', 'location': ''}, {'building_id': 176, 'building_name': 'Stong College', 'location': ''}, {'building_id': 177, 'building_name': 'Scott Library', 'location': ''}, {'building_id': 178, 'building_name': 'Sherman Health Science Research Centre', 'location': ''}, {'building_id': 179, 'building_name': 'Stedman Lecture Halls', 'location': ''}, {'building_id': 180, 'building_name':  ...
# Processing Record ID: 133, Name: Accolade Building East, Existing Location:
# Formatted address: Accolade+Building+East+York+University+Toronto+ON+Canada
# Fetched Coordinates for Accolade Building East: (43.7725551, -79.4993904)
# Updated buildings ID 133 with coordinates: 43.7725551, -79.4993904
# Processing Record ID: 134, Name: Accolade Building West, Existing Location:
# Formatted address: Accolade+Building+West+York+University+Toronto+ON+Canada
# Fetched Coordinates for Accolade Building West: (43.7725673, -79.50249029999999)
# Updated buildings ID 134 with coordinates: 43.7725673, -79.50249029999999
# Processing Record ID: 135, Name: Archives of Ontario, Existing Location:
# Formatted address: Archives+of+Ontario+York+University+Toronto+ON+Canada
# Fetched Coordinates for Archives of Ontario: (43.774849, -79.500379)
# Updated buildings ID 135 with coordinates: 43.774849, -79.500379
# Processing Record ID: 136, Name: Atkinson, Existing Location:
# Formatted address: Atkinson+York+University+Toronto+ON+Canada
# Fetched Coordinates for Atkinson: (43.7711122, -79.5024153)
# Updated buildings ID 136 with coordinates: 43.7711122, -79.5024153
# Processing Record ID: 137, Name: Norman Bethune College, Existing Location:
# Formatted address: Norman+Bethune+College+York+University+Toronto+ON+Canada
# Fetched Coordinates for Norman Bethune College: (43.77298880000001, -79.5088344)
# Updated buildings ID 137 with coordinates: 43.77298880000001, -79.5088344
# Processing Record ID: 138, Name: Bennett Centre for Student Services, Existing Location:
# Formatted address: Bennett+Centre+for+Student+Services+York+University+Toronto+ON+Canada
# Fetched Coordinates for Bennett Centre for Student Services: (43.7723176, -79.49868049999999)
# Updated buildings ID 138 with coordinates: 43.7723176, -79.49868049999999
# Processing Record ID: 139, Name: Bergeron Centre for Engineering Excellence, Existing Location:
# Formatted address: Bergeron+Centre+for+Engineering+Excellence+York+University+Toronto+ON+Canada
# Fetched Coordinates for Bergeron Centre for Engineering Excellence: (43.7722329, -79.50668879999999)
# Updated buildings ID 139 with coordinates: 43.7722329, -79.50668879999999
# Processing Record ID: 140, Name: Behavioural Sciences Building, Existing Location:
# Formatted address: Behavioural+Sciences+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Behavioural Sciences Building: (43.7735791, -79.5037334)
# Updated buildings ID 140 with coordinates: 43.7735791, -79.5037334
# Processing Record ID: 141, Name: Burton Auditorium, Existing Location:
# Formatted address: Burton+Auditorium+York+University+Toronto+ON+Canada
# Fetched Coordinates for Burton Auditorium: (43.7726615, -79.5018644)
# Updated buildings ID 141 with coordinates: 43.7726615, -79.5018644
# Processing Record ID: 142, Name: Chemistry Building, Existing Location:
# Formatted address: Chemistry+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Chemistry Building: (43.7732651, -79.5079184)
# Updated buildings ID 142 with coordinates: 43.7732651, -79.5079184
# Processing Record ID: 143, Name: Calumet College, Existing Location:
# Formatted address: Calumet+College+York+University+Toronto+ON+Canada
# Fetched Coordinates for Calumet College: (43.7728461, -79.50974830000001)
# Updated buildings ID 143 with coordinates: 43.7728461, -79.50974830000001
# Processing Record ID: 144, Name: The Joan & Martin Goldfarb Centre for Fine Arts, Existing Location:
# Formatted address: The+Joan+and+Martin+Goldfarb+Centre+for+Fine+Arts+York+University+Toronto+ON+Canada
# Fetched Coordinates for The Joan & Martin Goldfarb Centre for Fine Arts: (43.7720368, -79.50234010000001)
# Updated buildings ID 144 with coordinates: 43.7720368, -79.50234010000001
# Processing Record ID: 145, Name: Centre for Film and Theatre, Existing Location:
# Formatted address: Centre+for+Film+and+Theatre+York+University+Toronto+ON+Canada
# Fetched Coordinates for Centre for Film and Theatre: (43.7726696, -79.501145)
# Updated buildings ID 145 with coordinates: 43.7726696, -79.501145
# Processing Record ID: 146, Name: Curtis Lecture Halls, Existing Location:
# Formatted address: Curtis+Lecture+Halls+York+University+Toronto+ON+Canada
# Fetched Coordinates for Curtis Lecture Halls: (43.7731258, -79.5052743)
# Updated buildings ID 146 with coordinates: 43.7731258, -79.5052743
# Processing Record ID: 147, Name: Computer Methods Building, Existing Location:
# Formatted address: Computer+Methods+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Computer Methods Building: (43.778963, -79.49566850000001)
# Updated buildings ID 147 with coordinates: 43.778963, -79.49566850000001
# Processing Record ID: 148, Name: Central Square, Existing Location:
# Formatted address: Central+Square+York+University+Toronto+ON+Canada
# Fetched Coordinates for Central Square: (43.7728891, -79.50489999999999)
# Updated buildings ID 148 with coordinates: 43.7728891, -79.50489999999999
# Processing Record ID: 149, Name: Central Utilities Building, Existing Location:
# Formatted address: Central+Utilities+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Central Utilities Building: (43.7775545, -79.49877269999999)
# Updated buildings ID 149 with coordinates: 43.7775545, -79.49877269999999
# Processing Record ID: 150, Name: Dahdaleh Building (formerly TEL), Existing Location:
# Formatted address: Dahdaleh+Building+(formerly+TEL)+York+University+Toronto+ON+Canada
# Fetched Coordinates for Dahdaleh Building (formerly TEL): (43.7711574, -79.5007935)
# Updated buildings ID 150 with coordinates: 43.7711574, -79.5007935
# Processing Record ID: 151, Name: Executive Learning Centre, Existing Location:
# Formatted address: Executive+Learning+Centre+York+University+Toronto+ON+Canada
# Fetched Coordinates for Executive Learning Centre: (43.7729679, -79.4981284)
# Updated buildings ID 151 with coordinates: 43.7729679, -79.4981284
# Processing Record ID: 152, Name: Founders College, Existing Location:
# Formatted address: Founders+College+York+University+Toronto+ON+Canada
# Fetched Coordinates for Founders College: (43.77603, -79.50336)
# Updated buildings ID 152 with coordinates: 43.77603, -79.50336
# Processing Record ID: 153, Name: Frost Library (Glendon campus), Existing Location:
# Formatted address: Frost+Library+(Glendon+campus)+York+University+Toronto+ON+Canada
# Fetched Coordinates for Frost Library (Glendon campus): (43.7272494, -79.3761823)
# Updated buildings ID 153 with coordinates: 43.7272494, -79.3761823
# Processing Record ID: 154, Name: Farquharson Life Sciences, Existing Location:
# Formatted address: Farquharson+Life+Sciences+York+University+Toronto+ON+Canada
# Fetched Coordinates for Farquharson Life Sciences: (43.774297, -79.5046694)
# Updated buildings ID 154 with coordinates: 43.774297, -79.5046694
# Processing Record ID: 155, Name: Founders Tennis Court, Existing Location:
# Formatted address: Founders+Tennis+Court+York+University+Toronto+ON+Canada
# Fetched Coordinates for Founders Tennis Court: (43.7747961, -79.50806949999999)
# Updated buildings ID 155 with coordinates: 43.7747961, -79.50806949999999
# Processing Record ID: 156, Name: Glendon Hall (Glendon campus), Existing Location:
# Formatted address: Glendon+Hall+(Glendon+campus)+York+University+Toronto+ON+Canada
# Fetched Coordinates for Glendon Hall (Glendon campus): (43.7277093, -79.37660989999999)
# Updated buildings ID 156 with coordinates: 43.7277093, -79.37660989999999
# Processing Record ID: 157, Name: Lorna R. Marsden Honours Court & Welcome Centre, Existing Location:
# Formatted address: Lorna+R.+Marsden+Honours+Court+and+Welcome+Centre+York+University+Toronto+ON+Canada
# Fetched Coordinates for Lorna R. Marsden Honours Court & Welcome Centre: (43.774266, -79.49822569999999)
# Updated buildings ID 157 with coordinates: 43.774266, -79.49822569999999
# Processing Record ID: 158, Name: Hart House (Osgoode Hall Law School), Existing Location:
# Formatted address: Hart+House+(Osgoode+Hall+Law+School)+York+University+Toronto+ON+Canada
# Fetched Coordinates for Hart House (Osgoode Hall Law School): (43.7706164, -79.50511139999999)
# Updated buildings ID 158 with coordinates: 43.7706164, -79.50511139999999
# Processing Record ID: 159, Name: Health, Nursing and Environmental Studies Building, Existing Location:
# Formatted address: Health+Nursing+and+Environmental+Studies+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Health, Nursing and Environmental Studies Building: (43.7712852, -79.5045715)
# Updated buildings ID 159 with coordinates: 43.7712852, -79.5045715
# Processing Record ID: 160, Name: Hilliard Residence (Glendon campus), Existing Location:
# Formatted address: Hilliard+Residence+(Glendon+campus)+York+University+Toronto+ON+Canada
# Fetched Coordinates for Hilliard Residence (Glendon campus): (43.726258, -79.3780712)
# Updated buildings ID 160 with coordinates: 43.726258, -79.3780712
# Processing Record ID: 161, Name: Ignat Kaneff Building (Osgoode Hall Law School), Existing Location:
# Formatted address: Ignat+Kaneff+Building+(Osgoode+Hall+Law+School)+York+University+Toronto+ON+Canada
# Fetched Coordinates for Ignat Kaneff Building (Osgoode Hall Law School): (43.7706164, -79.50511139999999)
# Updated buildings ID 161 with coordinates: 43.7706164, -79.50511139999999
# Processing Record ID: 162, Name: Kinsmen Building, Existing Location:
# Formatted address: Kinsmen+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Kinsmen Building: (43.7780012, -79.49553070000002)
# Updated buildings ID 162 with coordinates: 43.7780012, -79.49553070000002
# Processing Record ID: 163, Name: Kaneff Tower, Existing Location:
# Formatted address: Kaneff+Tower+York+University+Toronto+ON+Canada
# Fetched Coordinates for Kaneff Tower: (43.7747818, -79.500619)
# Updated buildings ID 163 with coordinates: 43.7747818, -79.500619
# Processing Record ID: 164, Name: Lassonde Building, Existing Location:
# Formatted address: Lassonde+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Lassonde Building: (43.7742239, -79.5055648)
# Updated buildings ID 164 with coordinates: 43.7742239, -79.5055648
# Processing Record ID: 165, Name: LA&PS @ IBM Markham, Existing Location:
# Formatted address: LAandPS+@+IBM+Markham+York+University+Toronto+ON+Canada
# Fetched Coordinates for LA&PS @ IBM Markham: (43.85439, -79.31151)
# Updated buildings ID 165 with coordinates: 43.85439, -79.31151
# Processing Record ID: 166, Name: Life Sciences Building, Existing Location:
# Formatted address: Life+Sciences+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Life Sciences Building: (43.774174, -79.5079816)
# Updated buildings ID 166 with coordinates: 43.774174, -79.5079816
# Processing Record ID: 167, Name: Lumbers Building, Existing Location:
# Formatted address: Lumbers+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Lumbers Building: (43.7748183, -79.5049999)
# Updated buildings ID 167 with coordinates: 43.7748183, -79.5049999
# Processing Record ID: 168, Name: Rob and Cheryl McEwen Graduate Study & Research Building, Existing Location:
# Formatted address: Rob+and+Cheryl+McEwen+Graduate+Study+and+Research+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Rob and Cheryl McEwen Graduate Study & Research Building: (43.653226, -79.3831843)
# Updated buildings ID 168 with coordinates: 43.653226, -79.3831843
# Processing Record ID: 169, Name: McLaughlin College, Existing Location:
# Formatted address: McLaughlin+College+York+University+Toronto+ON+Canada
# Fetched Coordinates for McLaughlin College: (43.77716239999999, -79.5024348)
# Updated buildings ID 169 with coordinates: 43.77716239999999, -79.5024348
# Processing Record ID: 170, Name: Off Campus (contact the department that offers the course), Existing Location:
# Formatted address: Off+Campus+(contact+the+department+that+offers+the+course)+York+University+Toronto+ON+Canada
# Fetched Coordinates for Off Campus (contact the department that offers the course): (43.65446559999999, -79.3874936)
# Updated buildings ID 170 with coordinates: 43.65446559999999, -79.3874936
# Processing Record ID: 171, Name: Physical Resources Building, Existing Location:
# Formatted address: Physical+Resources+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Physical Resources Building: (43.777507, -79.4971978)
# Updated buildings ID 171 with coordinates: 43.777507, -79.4971978
# Processing Record ID: 172, Name: Petrie Science and Engineering Building / Petrie Observatory, Existing Location:
# Formatted address: Petrie+Science+and+Engineering+Building+/+Petrie+Observatory+York+University+Toronto+ON+Canada
# Fetched Coordinates for Petrie Science and Engineering Building / Petrie Observatory: (43.7739317, -79.5067754)
# Updated buildings ID 172 with coordinates: 43.7739317, -79.5067754
# Processing Record ID: 173, Name: Ross Building, Existing Location:
# Formatted address: Ross+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Ross Building: (43.7722433, -79.50379219999999)
# Updated buildings ID 173 with coordinates: 43.7722433, -79.50379219999999
# Processing Record ID: 175, Name: Seneca @ York, Existing Location:
# Formatted address: Seneca+@+York+York+University+Toronto+ON+Canada
# Fetched Coordinates for Seneca @ York: (43.7734535, -79.50186839999999)
# Updated buildings ID 175 with coordinates: 43.7734535, -79.50186839999999
# Processing Record ID: 176, Name: Stong College, Existing Location:
# Formatted address: Stong+College+York+University+Toronto+ON+Canada
# Fetched Coordinates for Stong College: (43.7728139, -79.5087235)
# Updated buildings ID 176 with coordinates: 43.7728139, -79.5087235
# Processing Record ID: 177, Name: Scott Library, Existing Location:
# Formatted address: Scott+Library+York+University+Toronto+ON+Canada
# Fetched Coordinates for Scott Library: (43.7723418, -79.5055508)
# Updated buildings ID 177 with coordinates: 43.7723418, -79.5055508
# Processing Record ID: 178, Name: Sherman Health Science Research Centre, Existing Location:
# Formatted address: Sherman+Health+Science+Research+Centre+York+University+Toronto+ON+Canada
# Fetched Coordinates for Sherman Health Science Research Centre: (43.7752117, -79.51194679999999)
# Updated buildings ID 178 with coordinates: 43.7752117, -79.51194679999999
# Processing Record ID: 179, Name: Stedman Lecture Halls, Existing Location:
# Formatted address: Stedman+Lecture+Halls+York+University+Toronto+ON+Canada
# Fetched Coordinates for Stedman Lecture Halls: (43.7743997, -79.50318419999999)
# Updated buildings ID 179 with coordinates: 43.7743997, -79.50318419999999
# Processing Record ID: 180, Name: Seymour Schulich Building, Existing Location:
# Formatted address: Seymour+Schulich+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for Seymour Schulich Building: (43.7734608, -79.4991869)
# Updated buildings ID 180 with coordinates: 43.7734608, -79.4991869
# Processing Record ID: 181, Name: Sheridan College - Trafalgar Campus, Existing Location:
# Formatted address: Sheridan+College+-+Trafalgar+Campus+York+University+Toronto+ON+Canada
# Fetched Coordinates for Sheridan College - Trafalgar Campus: (43.7729946, -79.5035369)
# Updated buildings ID 181 with coordinates: 43.7729946, -79.5035369
# Processing Record ID: 182, Name: Student Centre, Existing Location:
# Formatted address: Student+Centre+York+University+Toronto+ON+Canada
# Fetched Coordinates for Student Centre: (43.7738625, -79.50316190000001)
# Updated buildings ID 182 with coordinates: 43.7738625, -79.50316190000001
# Processing Record ID: 183, Name: Steacie Science and Engineering Library, Existing Location:
# Formatted address: Steacie+Science+and+Engineering+Library+York+University+Toronto+ON+Canada
# Fetched Coordinates for Steacie Science and Engineering Library: (43.773608, -79.505845)
# Updated buildings ID 183 with coordinates: 43.773608, -79.505845
# Processing Record ID: 184, Name: Tennis Canada (TC Sobeys), Existing Location:
# Formatted address: Tennis+Canada+(TC+Sobeys)+York+University+Toronto+ON+Canada
# Fetched Coordinates for Tennis Canada (TC Sobeys): (43.7707159, -79.5115709)
# Updated buildings ID 184 with coordinates: 43.7707159, -79.5115709
# Processing Record ID: 185, Name: Technology and Enhanced Learning Building (effective summer 2016, Dahdaleh Building, DB), Existing Location:
# Formatted address: Technology+and+Enhanced+Learning+Building+(effective+summer+2016+Dahdaleh+Building+DB)+York+University+Toronto+ON+Canada
# Fetched Coordinates for Technology and Enhanced Learning Building (effective summer 2016, Dahdaleh Building, DB): (43.7711574, -79.5007935)
# Updated buildings ID 185 with coordinates: 43.7711574, -79.5007935
# Processing Record ID: 186, Name: Track and Field Centre, Existing Location:
# Formatted address: Track+and+Field+Centre+York+University+Toronto+ON+Canada
# Fetched Coordinates for Track and Field Centre: (43.7763564, -79.50766449999999)
# Updated buildings ID 186 with coordinates: 43.7763564, -79.50766449999999
# Processing Record ID: 187, Name: Tait McKenzie Centre (East/West), Existing Location:
# Formatted address: Tait+McKenzie+Centre+(East/West)+York+University+Toronto+ON+Canada
# Fetched Coordinates for Tait McKenzie Centre (East/West): (43.7742311, -79.5094038)
# Updated buildings ID 187 with coordinates: 43.7742311, -79.5094038
# Processing Record ID: 188, Name: Tait Tennis Courts, Existing Location:
# Formatted address: Tait+Tennis+Courts+York+University+Toronto+ON+Canada
# Fetched Coordinates for Tait Tennis Courts: (43.7747961, -79.50806949999999)
# Updated buildings ID 188 with coordinates: 43.7747961, -79.50806949999999
# Processing Record ID: 189, Name: Vanier College, Existing Location:
# Formatted address: Vanier+College+York+University+Toronto+ON+Canada
# Fetched Coordinates for Vanier College: (43.7755814, -79.50221479999999)
# Updated buildings ID 189 with coordinates: 43.7755814, -79.50221479999999
# Processing Record ID: 190, Name: Vari Hall, Existing Location:
# Formatted address: Vari+Hall+York+University+Toronto+ON+Canada
# Fetched Coordinates for Vari Hall: (43.7730972, -79.5034042)
# Updated buildings ID 190 with coordinates: 43.7730972, -79.5034042
# Processing Record ID: 191, Name: Winters College, Existing Location:
# Formatted address: Winters+College+York+University+Toronto+ON+Canada
# Fetched Coordinates for Winters College: (43.77613030000001, -79.50160919999999)
# Updated buildings ID 191 with coordinates: 43.77613030000001, -79.50160919999999
# Processing Record ID: 192, Name: West Office Building, Existing Location:
# Formatted address: West+Office+Building+York+University+Toronto+ON+Canada
# Fetched Coordinates for West Office Building: (43.7753202, -79.50811759999999)
# Updated buildings ID 192 with coordinates: 43.7753202, -79.50811759999999
# Processing Record ID: 193, Name: William Small Centre, Existing Location:
# Formatted address: William+Small+Centre+York+University+Toronto+ON+Canada
# Fetched Coordinates for William Small Centre: (43.77294500000001, -79.50777769999999)
# Updated buildings ID 193 with coordinates: 43.77294500000001, -79.50777769999999
# Processing Record ID: 194, Name: York Hall (Glendon campus), Existing Location:
# Formatted address: York+Hall+(Glendon+campus)+York+University+Toronto+ON+Canada
# Fetched Coordinates for York Hall (Glendon campus): (43.727296, -79.3790337)
# Updated buildings ID 194 with coordinates: 43.727296, -79.3790337
# Processing Record ID: 195, Name: York Lanes, Existing Location:
# Formatted address: York+Lanes+York+University+Toronto+ON+Canada
# Fetched Coordinates for York Lanes: (43.7742143, -79.5018478)
# Updated buildings ID 195 with coordinates: 43.7742143, -79.5018478
# Processing Record ID: 196, Name: York Student Fieldhouse (East/West) (Tait McKenzie Building), Existing Location:
# Formatted address: York+Student+Fieldhouse+(East/West)+(Tait+McKenzie+Building)+York+University+Toronto+ON+Canada
# Fetched Coordinates for York Student Fieldhouse (East/West) (Tait McKenzie Building): (43.7745284, -79.5096745)
# Updated buildings ID 196 with coordinates: 43.7745284, -79.5096745
# Processing Record ID: 197, Name: York Student Fieldhouse (East side only) (Tait McKenzie Building), Existing Location:
# Formatted address: York+Student+Fieldhouse+(East+side+only)+(Tait+McKenzie+Building)+York+University+Toronto+ON+Canada
# Fetched Coordinates for York Student Fieldhouse (East side only) (Tait McKenzie Building): (43.7745284, -79.5096745)
# Updated buildings ID 197 with coordinates: 43.7745284, -79.5096745
# Processing Record ID: 198, Name: York Student Fieldhouse (West side only) (Tait McKenzie Building), Existing Location:
# Formatted address: York+Student+Fieldhouse+(West+side+only)+(Tait+McKenzie+Building)+York+University+Toronto+ON+Canada
# Fetched Coordinates for York Student Fieldhouse (West side only) (Tait McKenzie Building): (43.7745284, -79.5096745)
# Updated buildings ID 198 with coordinates: 43.7745284, -79.5096745
# Finished updating buildings.
