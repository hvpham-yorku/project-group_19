# %% [markdown]
# ## Loading the Database

# %%
import sys
import os

import mysql.connector
from mysql.connector import Error
import json
from datetime import datetime, timedelta

# Add the project root to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
if project_root not in sys.path:
    sys.path.append(project_root)
    
from app.database import create_connection  # Replace `function_name` with the specific function you want to import

connection = create_connection()

# %% [markdown]
# ## Insert Buildings, rooms, and avaiability

# %%
def load_buildings(connection, buildings):
    """
    Inserts building data into the buildings table.
    :param connection: MySQL connection
    :param buildings: Dictionary of building codes and names
    """
    cursor = connection.cursor()
    try:
        for code, name in buildings.items():
            cursor.execute("""
                INSERT IGNORE INTO buildings (building_code, building_name)
                VALUES (%s, %s);
            """, (code, name))
        connection.commit()
        print("Buildings loaded successfully!")
    except mysql.connector.Error as e:
        print(f"Error loading buildings: {e}")
    finally:
        cursor.close()



# Load buildings
buildings = {
    "ACE": "Accolade Building East",
    "ACW": "Accolade Building West",
    "AO": "Archives of Ontario",
    "ATK": "Atkinson",
    "BC": "Norman Bethune College",
    "BCSS": "Bennett Centre for Student Services",
    "BRG": "Bergeron Centre for Engineering Excellence",
    "BSB": "Behavioural Sciences Building",
    "BU": "Burton Auditorium",
    "CB": "Chemistry Building",
    "CC": "Calumet College",
    "CFA": "The Joan & Martin Goldfarb Centre for Fine Arts",
    "CFT": "Centre for Film and Theatre",
    "CLH": "Curtis Lecture Halls",
    "CMB": "Computer Methods Building",
    "CSQ": "Central Square",
    "CUB": "Central Utilities Building",
    "DB": "Dahdaleh Building (formerly TEL)",
    "ELC": "Executive Learning Centre",
    "FC": "Founders College",
    "FL": "Frost Library (Glendon campus)",
    "FRQ": "Farquharson Life Sciences",
    "FTC": "Founders Tennis Court",
    "GH": "Glendon Hall (Glendon campus)",
    "HC": "Lorna R. Marsden Honours Court & Welcome Centre",
    "HH": "Hart House (Osgoode Hall Law School)",
    "HNE": "Health, Nursing and Environmental Studies Building",
    "HR": "Hilliard Residence (Glendon campus)",
    "IKB": "Ignat Kaneff Building (Osgoode Hall Law School)",
    "K": "Kinsmen Building",
    "KT": "Kaneff Tower",
    "LAS": "Lassonde Building",
    "LMP": "LA&PS @ IBM Markham",
    "LSB": "Life Sciences Building",
    "LUM": "Lumbers Building",
    "MB": "Rob and Cheryl McEwen Graduate Study & Research Building",
    "MC": "McLaughlin College",
    "OC": "Off Campus (contact the department that offers the course)",
    "PR": "Physical Resources Building",
    "PSE": "Petrie Science and Engineering Building / Petrie Observatory",
    "R N": "Ross Building - North wing",
    "R S": "Ross Building - South wing",
    "SAY": "Seneca @ York",
    "SC": "Stong College",
    "SCL": "Scott Library",
    "SHR": "Sherman Health Science Research Centre",
    "SLH": "Stedman Lecture Halls",
    "SSB": "Seymour Schulich Building",
    "ST": "Sheridan College - Trafalgar Campus",
    "STC": "Student Centre",
    "STL": "Steacie Science and Engineering Library",
    "TC Sobeys": "Tennis Canada (TC Sobeys)",
    "TEL": "Technology and Enhanced Learning Building (effective summer 2016, Dahdaleh Building, DB)",
    "TFC": "Track and Field Centre",
    "TM Tait": "Tait McKenzie Centre (East/West)",
    "TTC": "Tait Tennis Courts",
    "VC": "Vanier College",
    "VH": "Vari Hall",
    "WC": "Winters College",
    "WOB": "West Office Building",
    "WSC": "William Small Centre",
    "YH": "York Hall (Glendon campus)",
    "YL": "York Lanes",
    "YSF FLDHSE": "York Student Fieldhouse (East/West) (Tait McKenzie Building)",
    "YSF FLDHSEE": "York Student Fieldhouse (East side only) (Tait McKenzie Building)",
    "YSF FLDHSEW": "York Student Fieldhouse (West side only) (Tait McKenzie Building)",
}
load_buildings(connection, buildings)
print("success")
# Out:
# Buildings loaded successfully!
# success

# %%
from datetime import datetime, timedelta

def load_rooms_and_availabilities(connection, data):
    """
    Inserts rooms into the database and calculates unoccupied time slots (availability).
    Handles full-day availability if a room is unoccupied for a given day.
    Includes all days from Monday to Sunday.
    :param connection: Active MySQL connection.
    :param data: Dictionary of room_name -> schedules.
    """
    try:
        cursor = connection.cursor()

        # Operating hours: 8:30 AM to 10:00 PM
        opening_time = datetime.strptime("08:30", "%H:%M")
        closing_time = datetime.strptime("22:00", "%H:%M")

        valid_days = {"M", "T", "W", "R", "F", "S", "U"}  # Include all days of the week

        for room_name, schedules in data.items():
            # Split the room name to get building code and room number
            parts = room_name.split(" ", 1)
            if len(parts) < 2:
                print(f"Invalid room name format: {room_name}. Skipping.")
                continue
            building_code, room_number = parts[0], parts[1]

            # Find building_id using building_code
            cursor.execute("SELECT building_id FROM buildings WHERE building_code = %s", (building_code,))
            result = cursor.fetchone()
            if not result:
                print(f"Building not found for code {building_code}. Skipping.")
                continue

            building_id = result[0]

            # Insert room into database
            cursor.execute("""
                INSERT INTO rooms (building_id, room_name)
                VALUES (%s, %s);
            """, (building_id, room_name))
            room_id = cursor.lastrowid
            print(f"Inserted room: {room_name}, ID: {room_id}")

            # Group occupied time slots by day
            occupied_slots = {day: [] for day in valid_days}
            for schedule in schedules:
                day = schedule.get("day")
                if day not in valid_days:
                    print(f"Invalid day code: {day}. Skipping.")
                    continue

                start_time = datetime.strptime(schedule["time"], "%H:%M")
                duration_minutes = int(schedule["duration"])
                end_time = start_time + timedelta(minutes=duration_minutes)
                occupied_slots[day].append((start_time, end_time))

            # Calculate unoccupied time slots for each day
            for day in valid_days:
                slots = occupied_slots[day]
                if not slots:
                    # Room is completely free for the entire day
                    cursor.execute("""
                        INSERT INTO availabilities (room_id, start_time, end_time, day)
                        VALUES (%s, %s, %s, %s);
                    """, (
                        room_id,
                        opening_time.strftime("%H:%M:%S"),
                        closing_time.strftime("%H:%M:%S"),
                        day
                    ))
                    print(f"Inserted full-day free slot: Room {room_name}, Day: {day}, Start: {opening_time}, End: {closing_time}")
                else:
                    # Sort occupied slots by start time
                    slots.sort(key=lambda x: x[0])
                    current_time = opening_time

                    for start, end in slots:
                        if current_time < start:
                            # Add unoccupied time before the next occupied slot
                            cursor.execute("""
                                INSERT INTO availabilities (room_id, start_time, end_time, day)
                                VALUES (%s, %s, %s, %s);
                            """, (
                                room_id,
                                current_time.strftime("%H:%M:%S"),
                                start.strftime("%H:%M:%S"),
                                day
                            ))
                            print(f"Inserted free slot: Room {room_name}, Day: {day}, Start: {current_time}, End: {start}")
                        current_time = max(current_time, end)

                    # Add remaining unoccupied time after the last occupied slot
                    if current_time < closing_time:
                        cursor.execute("""
                            INSERT INTO availabilities (room_id, start_time, end_time, day)
                            VALUES (%s, %s, %s, %s);
                        """, (
                            room_id,
                            current_time.strftime("%H:%M:%S"),
                            closing_time.strftime("%H:%M:%S"),
                            day
                        ))
                        print(f"Inserted free slot: Room {room_name}, Day: {day}, Start: {current_time}, End: {closing_time}")

        connection.commit()
        print("Rooms and availabilities loaded successfully.")
    except Exception as e:
        print(f"Error loading rooms and availabilities: {e}")
    finally:
        cursor.close()

# %%
# Establish connection
connection = create_connection()

# Load rooms and availabilities from JSON
import json
with open("../scraped backup/emptyrooms_fw24/all_rooms_2024_09_11.json", "r") as f:
    room_data = json.load(f)

load_rooms_and_availabilities(connection, room_data)
# Out:
# Inserted room: WC 117, ID: 2376
# Inserted free slot: Room WC 117, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room WC 117, Day: M, Start: 1900-01-01 11:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room WC 117, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room WC 117, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room WC 117, Day: W, Start: 1900-01-01 20:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room WC 117, Day: F, Start: 1900-01-01 11:30:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room WC 117, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room WC 117, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room WC 117, Day: T, Start: 1900-01-01 11:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room WC 117, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room WC 117, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room WC 117, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room WC 117, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room WC 117, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB N109, ID: 2377
# Inserted free slot: Room SSB N109, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N109, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N109, Day: F, Start: 1900-01-01 09:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N109, Day: F, Start: 1900-01-01 11:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N109, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N109, Day: R, Start: 1900-01-01 09:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N109, Day: R, Start: 1900-01-01 11:00:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N109, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room SSB N109, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N109, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Invalid room name format: . Skipping.
# Inserted room: SSB N106, ID: 2378
# Inserted free slot: Room SSB N106, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N106, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N106, Day: F, Start: 1900-01-01 09:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N106, Day: F, Start: 1900-01-01 11:00:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N106, Day: F, Start: 1900-01-01 12:30:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB N106, Day: F, Start: 1900-01-01 14:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N106, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room SSB N106, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N106, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB W141, ID: 2379
# Inserted free slot: Room SSB W141, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB W141, Day: M, Start: 1900-01-01 16:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W141, Day: W, Start: 1900-01-01 10:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W141, Day: W, Start: 1900-01-01 15:30:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SSB W141, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W141, Day: F, Start: 1900-01-01 10:30:00, End: 1900-01-01 11:00:00
# Inserted free slot: Room SSB W141, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W141, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W141, Day: T, Start: 1900-01-01 14:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W141, Day: R, Start: 1900-01-01 10:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W141, Day: R, Start: 1900-01-01 13:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W141, Day: R, Start: 1900-01-01 16:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W141, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W141, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB N108, ID: 2380
# Inserted free slot: Room SSB N108, Day: M, Start: 1900-01-01 11:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N108, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N108, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room SSB N108, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N108, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB N108, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room SSB N108, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N108, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB N105, ID: 2381
# Inserted free slot: Room SSB N105, Day: M, Start: 1900-01-01 11:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB N105, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 18:30:00
# Inserted free slot: Room SSB N105, Day: M, Start: 1900-01-01 21:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N105, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N105, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N105, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room SSB N105, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N105, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB W132, ID: 2382
# Inserted free slot: Room SSB W132, Day: M, Start: 1900-01-01 11:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W132, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB W132, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 18:30:00
# Inserted full-day free slot: Room SSB W132, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W132, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB W132, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W132, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W132, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 18:30:00
# Inserted full-day free slot: Room SSB W132, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W132, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB E111, ID: 2383
# Inserted free slot: Room SSB E111, Day: M, Start: 1900-01-01 11:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E111, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E111, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room SSB E111, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E111, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SSB E111, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E111, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E111, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E111, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB E112, ID: 2384
# Inserted free slot: Room SSB E112, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E112, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E112, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E112, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room SSB E112, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E112, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB E118, ID: 2385
# Inserted free slot: Room SSB E118, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E118, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E118, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E118, Day: R, Start: 1900-01-01 11:30:00, End: 1900-01-01 14:30:00
# Inserted full-day free slot: Room SSB E118, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E118, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB W257, ID: 2386
# Inserted free slot: Room SSB W257, Day: M, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W257, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W257, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W257, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W257, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W257, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W257, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W257, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W257, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W257, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB E115, ID: 2387
# Inserted free slot: Room SSB E115, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB E115, Day: F, Start: 1900-01-01 11:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB E115, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 18:30:00
# Inserted full-day free slot: Room SSB E115, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB E115, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB S126, ID: 2388
# Inserted free slot: Room SSB S126, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S126, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB S126, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S126, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB S126, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room SSB S126, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S126, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB W136, ID: 2389
# Inserted free slot: Room SSB W136, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB W136, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB W136, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 18:30:00
# Inserted free slot: Room SSB W136, Day: F, Start: 1900-01-01 11:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W136, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room SSB W136, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W136, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB N107, ID: 2390
# Inserted free slot: Room SSB N107, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N107, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N107, Day: F, Start: 1900-01-01 09:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SSB N107, Day: F, Start: 1900-01-01 11:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB N107, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB N107, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room SSB N107, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB N107, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB S124, ID: 2391
# Inserted free slot: Room SSB S124, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S124, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S124, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S124, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB S124, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S124, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S124, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB W133, ID: 2392
# Inserted free slot: Room SSB W133, Day: M, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W133, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 18:30:00
# Inserted free slot: Room SSB W133, Day: W, Start: 1900-01-01 21:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W133, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room SSB W133, Day: F, Start: 1900-01-01 12:00:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SSB W133, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB W133, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SSB W133, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted full-day free slot: Room SSB W133, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB W133, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: MB G102, ID: 2393
# Inserted free slot: Room MB G102, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room MB G102, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room MB G102, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G102, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 18:30:00
# Inserted free slot: Room MB G102, Day: T, Start: 1900-01-01 21:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G102, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room MB G102, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MB G102, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: MB G105, ID: 2394
# Inserted free slot: Room MB G105, Day: M, Start: 1900-01-01 14:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room MB G105, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room MB G105, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G105, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G105, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room MB G105, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room MB G105, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MB G105, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: MB G101, ID: 2395
# Inserted free slot: Room MB G101, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room MB G101, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room MB G101, Day: W, Start: 1900-01-01 11:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room MB G101, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room MB G101, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MB G101, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MB G101, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MB G101, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SSB S125, ID: 2396
# Inserted free slot: Room SSB S125, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S125, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S125, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S125, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S125, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S125, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S125, Day: T, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SSB S125, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SSB S125, Day: R, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S125, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SSB S125, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SLH D, ID: 2397
# Inserted free slot: Room SLH D, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room SLH D, Day: M, Start: 1900-01-01 16:30:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room SLH D, Day: M, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH D, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room SLH D, Day: W, Start: 1900-01-01 13:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SLH D, Day: W, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH D, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room SLH D, Day: F, Start: 1900-01-01 10:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH D, Day: F, Start: 1900-01-01 16:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH D, Day: T, Start: 1900-01-01 13:00:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SLH D, Day: T, Start: 1900-01-01 18:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SLH D, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room SLH D, Day: R, Start: 1900-01-01 13:00:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room SLH D, Day: R, Start: 1900-01-01 18:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SLH D, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SLH D, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SLH A, ID: 2398
# Inserted free slot: Room SLH A, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room SLH A, Day: W, Start: 1900-01-01 18:00:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SLH A, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room SLH A, Day: F, Start: 1900-01-01 12:30:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SLH A, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH A, Day: T, Start: 1900-01-01 12:00:00, End: 1900-01-01 12:30:00
# Inserted free slot: Room SLH A, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SLH A, Day: R, Start: 1900-01-01 12:00:00, End: 1900-01-01 12:30:00
# Inserted full-day free slot: Room SLH A, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SLH A, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SLH F, ID: 2399
# Inserted free slot: Room SLH F, Day: M, Start: 1900-01-01 15:00:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SLH F, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH F, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SLH F, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted full-day free slot: Room SLH F, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SLH F, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CLH B, ID: 2400
# Inserted free slot: Room CLH B, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CLH B, Day: M, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH B, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CLH B, Day: W, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH B, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CLH B, Day: F, Start: 1900-01-01 15:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH B, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room CLH B, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room CLH B, Day: R, Start: 1900-01-01 16:30:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room CLH B, Day: R, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH B, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH B, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Building not found for code MK. Skipping.
# Inserted room: VH D, ID: 2401
# Inserted free slot: Room VH D, Day: M, Start: 1900-01-01 13:00:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room VH D, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room VH D, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room VH D, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room VH D, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room VH D, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room VH D, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room VH D, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room VH D, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Building not found for code MK. Skipping.
# Inserted room: VH C, ID: 2402
# Inserted free slot: Room VH C, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room VH C, Day: M, Start: 1900-01-01 19:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room VH C, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room VH C, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room VH C, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room VH C, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room VH C, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room VH C, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room VH C, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Building not found for code MK. Skipping.
# Inserted room: DB 0014, ID: 2403
# Inserted free slot: Room DB 0014, Day: M, Start: 1900-01-01 14:30:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room DB 0014, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room DB 0014, Day: W, Start: 1900-01-01 16:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room DB 0014, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room DB 0014, Day: F, Start: 1900-01-01 13:00:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room DB 0014, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room DB 0014, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room DB 0014, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room DB 0014, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted full-day free slot: Room DB 0014, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room DB 0014, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: HNE 038, ID: 2404
# Inserted free slot: Room HNE 038, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room HNE 038, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room HNE 038, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room HNE 038, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room HNE 038, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room HNE 038, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room HNE 038, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room HNE 038, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room HNE 038, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room HNE 038, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CLH G, ID: 2405
# Inserted free slot: Room CLH G, Day: M, Start: 1900-01-01 10:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CLH G, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH G, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room CLH G, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH G, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH G, Day: T, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH G, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room CLH G, Day: R, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH G, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH G, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CLH D, ID: 2406
# Inserted free slot: Room CLH D, Day: M, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH D, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CLH D, Day: W, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH D, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CLH D, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH D, Day: T, Start: 1900-01-01 16:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH D, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH D, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH D, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: DB 0010, ID: 2407
# Inserted free slot: Room DB 0010, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room DB 0010, Day: W, Start: 1900-01-01 17:00:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room DB 0010, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room DB 0010, Day: F, Start: 1900-01-01 12:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room DB 0010, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room DB 0010, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room DB 0010, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted full-day free slot: Room DB 0010, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room DB 0010, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: DB 0006, ID: 2408
# Inserted free slot: Room DB 0006, Day: M, Start: 1900-01-01 10:00:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room DB 0006, Day: M, Start: 1900-01-01 18:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room DB 0006, Day: W, Start: 1900-01-01 10:00:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room DB 0006, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room DB 0006, Day: F, Start: 1900-01-01 16:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room DB 0006, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room DB 0006, Day: R, Start: 1900-01-01 12:30:00, End: 1900-01-01 14:30:00
# Inserted full-day free slot: Room DB 0006, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room DB 0006, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: ACW 005, ID: 2409
# Inserted free slot: Room ACW 005, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room ACW 005, Day: M, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 005, Day: W, Start: 1900-01-01 16:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room ACW 005, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 005, Day: T, Start: 1900-01-01 09:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room ACW 005, Day: T, Start: 1900-01-01 16:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 005, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room ACW 005, Day: R, Start: 1900-01-01 16:00:00, End: 1900-01-01 16:30:00
# Inserted free slot: Room ACW 005, Day: R, Start: 1900-01-01 18:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACW 005, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACW 005, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFA 312, ID: 2410
# Inserted free slot: Room CFA 312, Day: M, Start: 1900-01-01 11:00:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFA 312, Day: M, Start: 1900-01-01 14:30:00, End: 1900-01-01 15:00:00
# Inserted free slot: Room CFA 312, Day: M, Start: 1900-01-01 16:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 312, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFA 312, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFA 312, Day: F, Start: 1900-01-01 13:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFA 312, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 312, Day: T, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 312, Day: R, Start: 1900-01-01 11:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFA 312, Day: R, Start: 1900-01-01 15:30:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room CFA 312, Day: R, Start: 1900-01-01 20:00:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 312, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 312, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: ACW 004, ID: 2411
# Inserted free slot: Room ACW 004, Day: M, Start: 1900-01-01 10:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACW 004, Day: M, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 004, Day: W, Start: 1900-01-01 16:30:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room ACW 004, Day: W, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 004, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACW 004, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 004, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room ACW 004, Day: T, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 004, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room ACW 004, Day: R, Start: 1900-01-01 21:00:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACW 004, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACW 004, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: DB 0016, ID: 2412
# Inserted free slot: Room DB 0016, Day: M, Start: 1900-01-01 16:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room DB 0016, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room DB 0016, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room DB 0016, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room DB 0016, Day: F, Start: 1900-01-01 13:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room DB 0016, Day: F, Start: 1900-01-01 16:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room DB 0016, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:00:00
# Inserted free slot: Room DB 0016, Day: R, Start: 1900-01-01 16:00:00, End: 1900-01-01 16:30:00
# Inserted free slot: Room DB 0016, Day: R, Start: 1900-01-01 18:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room DB 0016, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room DB 0016, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CLH E, ID: 2413
# Inserted free slot: Room CLH E, Day: M, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH E, Day: F, Start: 1900-01-01 15:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH E, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room CLH E, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room CLH E, Day: R, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH E, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH E, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SLH E, ID: 2414
# Inserted free slot: Room SLH E, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room SLH E, Day: M, Start: 1900-01-01 10:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH E, Day: M, Start: 1900-01-01 12:30:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SLH E, Day: M, Start: 1900-01-01 14:30:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SLH E, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room SLH E, Day: W, Start: 1900-01-01 10:30:00, End: 1900-01-01 13:00:00
# Inserted free slot: Room SLH E, Day: W, Start: 1900-01-01 15:30:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SLH E, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH E, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH E, Day: T, Start: 1900-01-01 18:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room SLH E, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room SLH E, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SLH E, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: SLH B, ID: 2415
# Inserted free slot: Room SLH B, Day: M, Start: 1900-01-01 10:00:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH B, Day: M, Start: 1900-01-01 13:00:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room SLH B, Day: W, Start: 1900-01-01 10:00:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH B, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room SLH B, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room SLH B, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room SLH B, Day: T, Start: 1900-01-01 15:30:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room SLH B, Day: R, Start: 1900-01-01 13:00:00, End: 1900-01-01 13:30:00
# Inserted full-day free slot: Room SLH B, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room SLH B, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: ACE 001, ID: 2416
# Inserted free slot: Room ACE 001, Day: M, Start: 1900-01-01 16:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 001, Day: W, Start: 1900-01-01 15:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 001, Day: F, Start: 1900-01-01 15:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 001, Day: T, Start: 1900-01-01 18:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room ACE 001, Day: T, Start: 1900-01-01 21:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 001, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 001, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 001, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: R N203, ID: 2417
# Inserted free slot: Room R N203, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room R N203, Day: M, Start: 1900-01-01 10:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room R N203, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room R N203, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room R N203, Day: W, Start: 1900-01-01 10:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room R N203, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room R N203, Day: T, Start: 1900-01-01 13:00:00, End: 1900-01-01 14:00:00
# Inserted free slot: Room R N203, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room R N203, Day: R, Start: 1900-01-01 15:30:00, End: 1900-01-01 19:00:00
# Inserted full-day free slot: Room R N203, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R N203, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: ACW 006, ID: 2418
# Inserted free slot: Room ACW 006, Day: M, Start: 1900-01-01 19:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 006, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room ACW 006, Day: W, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 006, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACW 006, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 006, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room ACW 006, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 006, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room ACW 006, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACW 006, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACW 006, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: R N102, ID: 2419
# Inserted free slot: Room R N102, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room R N102, Day: M, Start: 1900-01-01 18:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room R N102, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room R N102, Day: W, Start: 1900-01-01 12:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room R N102, Day: W, Start: 1900-01-01 18:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R N102, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room R N102, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room R N102, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room R N102, Day: R, Start: 1900-01-01 12:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R N102, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R N102, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: DB 0001, ID: 2420
# Inserted free slot: Room DB 0001, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room DB 0001, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room DB 0001, Day: F, Start: 1900-01-01 16:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room DB 0001, Day: T, Start: 1900-01-01 20:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room DB 0001, Day: R, Start: 1900-01-01 20:00:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room DB 0001, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room DB 0001, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CLH A, ID: 2421
# Inserted free slot: Room CLH A, Day: M, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH A, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room CLH A, Day: W, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH A, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CLH A, Day: F, Start: 1900-01-01 13:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH A, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 19:00:00
# Inserted free slot: Room CLH A, Day: R, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH A, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH A, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CLH C, ID: 2422
# Inserted free slot: Room CLH C, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CLH C, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH C, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CLH C, Day: W, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH C, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CLH C, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CLH C, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room CLH C, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room CLH C, Day: R, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH C, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CLH C, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: ACW 307, ID: 2423
# Inserted free slot: Room ACW 307, Day: M, Start: 1900-01-01 16:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 307, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACW 307, Day: W, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 307, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACW 307, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 307, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACW 307, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACW 307, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACW 307, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACW 307, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACW 307, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: ACE 013, ID: 2424
# Inserted free slot: Room ACE 013, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:30:00
# Inserted free slot: Room ACE 013, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 013, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACE 013, Day: W, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 013, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 013, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 013, Day: R, Start: 1900-01-01 11:30:00, End: 1900-01-01 12:30:00
# Inserted free slot: Room ACE 013, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 013, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 013, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: BRG 313, ID: 2425
# Inserted free slot: Room BRG 313, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room BRG 313, Day: M, Start: 1900-01-01 14:30:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room BRG 313, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room BRG 313, Day: W, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room BRG 313, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:00:00
# Inserted free slot: Room BRG 313, Day: F, Start: 1900-01-01 12:30:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room BRG 313, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room BRG 313, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:00:00
# ...
# Inserted free slot: Room MC 001, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MC 001, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MC 001, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room MC 001, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room MC 001, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room MC 001, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MC 001, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room MC 001, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: R S822, ID: 2833
# Inserted full-day free slot: Room R S822, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room R S822, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room R S822, Day: W, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S822, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S822, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S822, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S822, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S822, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: R S841, ID: 2834
# Inserted full-day free slot: Room R S841, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room R S841, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room R S841, Day: W, Start: 1900-01-01 14:30:00, End: 1900-01-01 16:00:00
# Inserted free slot: Room R S841, Day: W, Start: 1900-01-01 19:00:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S841, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S841, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room R S841, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room R S841, Day: R, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S841, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S841, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: R S840, ID: 2835
# Inserted full-day free slot: Room R S840, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S840, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S840, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S840, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room R S840, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room R S840, Day: R, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S840, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room R S840, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: ACE 209, ID: 2836
# Inserted free slot: Room ACE 209, Day: M, Start: 1900-01-01 20:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 209, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACE 209, Day: W, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 209, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room ACE 209, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 209, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ACE 209, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 209, Day: R, Start: 1900-01-01 11:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ACE 209, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 209, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 209, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: ACE 132, ID: 2837
# Inserted free slot: Room ACE 132, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 17:30:00
# Inserted free slot: Room ACE 132, Day: M, Start: 1900-01-01 20:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 132, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ACE 132, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 132, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ACE 132, Day: T, Start: 1900-01-01 11:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 132, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 132, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ACE 132, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 105A, ID: 2838
# Inserted full-day free slot: Room CFT 105A, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 105A, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFT 105A, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 105A, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 105A, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 105A, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 105A, Day: T, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 105A, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 105A, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 105A, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 105A, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 142, ID: 2839
# Inserted free slot: Room CFT 142, Day: M, Start: 1900-01-01 11:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFT 142, Day: M, Start: 1900-01-01 20:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 142, Day: W, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 142, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 142, Day: F, Start: 1900-01-01 13:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 142, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 142, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:00:00
# Inserted free slot: Room CFT 142, Day: R, Start: 1900-01-01 13:00:00, End: 1900-01-01 14:00:00
# Inserted free slot: Room CFT 142, Day: R, Start: 1900-01-01 17:00:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 142, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 142, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: ATK 102F, ID: 2840
# Inserted free slot: Room ATK 102F, Day: M, Start: 1900-01-01 20:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ATK 102F, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room ATK 102F, Day: W, Start: 1900-01-01 13:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ATK 102F, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room ATK 102F, Day: F, Start: 1900-01-01 11:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ATK 102F, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room ATK 102F, Day: T, Start: 1900-01-01 13:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ATK 102F, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room ATK 102F, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room ATK 102F, Day: R, Start: 1900-01-01 13:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room ATK 102F, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ATK 102F, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room ATK 102F, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 154, ID: 2841
# Inserted full-day free slot: Room CFT 154, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 154, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 154, Day: W, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 154, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 154, Day: F, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 154, Day: T, Start: 1900-01-01 11:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 154, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 154, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 154, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 157, ID: 2842
# Inserted full-day free slot: Room CFT 157, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 157, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 157, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 157, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 157, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 157, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 157, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 157, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 301, ID: 2843
# Inserted free slot: Room CFT 301, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 301, Day: M, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 301, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 301, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 10:00:00
# Inserted free slot: Room CFT 301, Day: F, Start: 1900-01-01 11:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 301, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 301, Day: T, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 301, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 301, Day: R, Start: 1900-01-01 14:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 301, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 301, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFT 155, ID: 2844
# Inserted full-day free slot: Room CFT 155, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 155, Day: W, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 155, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 155, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFT 155, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 11:30:00
# Inserted free slot: Room CFT 155, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 155, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFT 155, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFA 282, ID: 2845
# Inserted free slot: Room CFA 282, Day: M, Start: 1900-01-01 12:30:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 282, Day: M, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 282, Day: W, Start: 1900-01-01 12:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFA 282, Day: W, Start: 1900-01-01 18:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 282, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 282, Day: T, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 282, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 282, Day: R, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 282, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 282, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFA 284, ID: 2846
# Inserted free slot: Room CFA 284, Day: M, Start: 1900-01-01 12:30:00, End: 1900-01-01 13:30:00
# Inserted free slot: Room CFA 284, Day: M, Start: 1900-01-01 21:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 284, Day: W, Start: 1900-01-01 12:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFA 284, Day: W, Start: 1900-01-01 20:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 284, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFA 284, Day: F, Start: 1900-01-01 17:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 284, Day: T, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFA 284, Day: T, Start: 1900-01-01 18:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 284, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFA 284, Day: R, Start: 1900-01-01 21:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 284, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 284, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted room: CFA 106, ID: 2847
# Inserted free slot: Room CFA 106, Day: M, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFA 106, Day: M, Start: 1900-01-01 13:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 106, Day: W, Start: 1900-01-01 12:30:00, End: 1900-01-01 14:30:00
# Inserted free slot: Room CFA 106, Day: W, Start: 1900-01-01 18:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 106, Day: F, Start: 1900-01-01 08:30:00, End: 1900-01-01 09:30:00
# Inserted free slot: Room CFA 106, Day: F, Start: 1900-01-01 13:30:00, End: 1900-01-01 22:00:00
# Inserted free slot: Room CFA 106, Day: T, Start: 1900-01-01 12:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 106, Day: R, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 106, Day: U, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Inserted full-day free slot: Room CFA 106, Day: S, Start: 1900-01-01 08:30:00, End: 1900-01-01 22:00:00
# Rooms and availabilities loaded successfully.

# %% [markdown]
# # Testing Cafes and Libraries

# %%
import sys
import os

import mysql.connector
from mysql.connector import Error
import json
from datetime import datetime, timedelta

# Add the project root to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

from database import get_cafes, get_libraries

cafes = get_cafes()

print(cafes)

libraries = get_libraries()

print(libraries)
